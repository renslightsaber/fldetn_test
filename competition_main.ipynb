# %%
from competition_utils import *

# 제출 함수를 리스트로 정의 (submission_N_학번)
# 깃허브에는 최대 3개 업로드 데모시 하이퍼파라미터 튜닝 후 1개만 제출
submission_functions = ['submission_2_2023220397']  
for submission_function in submission_functions:
    exec(f"from {submission_function} import {submission_function}")

# 분석 방향에 따라 iteration 수 수정
# 평가시에는 데모와 다른 스플릿 시드를 만들어 [1, 10]로 진행 예정
iterations = [1, 10] 

# 'Crown Detection'는 예제 데이터셋, 데모 및 평가시에는 'CV_Competition'
Dataset_Name = 'Crown Detection' 

# 결과를 모아 하나의 csv 파일에 저장
results_df = pd.DataFrame(columns=[
    'Experiment Time', 'Iteration', 'Submission Function', 
    'IoU', 'Dice', 'Precision', 'Recall', 'Output Json Path',
])
csv_filename = f"Evaluation_Results_{datetime.now().strftime('%y%m%d_%H%M%S')}.csv"

# 서로 다른 iteration, submission function으로 실험 진행
for iteration in range(iterations[0], iterations[1]+1):
    yaml_path = f'Datasets/{Dataset_Name}/data_iter_{iteration:02d}.yaml'
    for submission_function in submission_functions:
        ex_time = datetime.now().strftime('%y%m%d_%H%M%S')
        output_json_path = f"{ex_time}_{submission_function}_Iter_{iteration}_detection_results.json"
        globals()[submission_function](yaml_path, output_json_path)
        labels_dir = f"Datasets/{Dataset_Name}/labels"  
        vis_output_dir = f"{ex_time}_visualization_results"  
        image_level_result_path =f"{ex_time}_{submission_function}_Iter_{iteration}_image_level_results.json"
        stats = eval_and_vis(yaml_path, output_json_path, labels_dir, image_level_result_path, vis_output_dir, vis=False) # 분석 방향에 따라 vis=True 설정
        new_row = {
            'Experiment Time': ex_time,
            'Iteration': iteration,
            'Submission Function': submission_function,
            'IoU': stats['IoU']['avg'],
            'Dice': stats['Dice']['avg'],
            'Precision': stats['Precision']['avg'],
            'Recall': stats['Recall']['avg'],
            'Output Json Path': output_json_path,
        }
        results_df = pd.concat([results_df, pd.DataFrame([new_row])], ignore_index=True)
        results_df.to_csv(csv_filename, index=False)
# Out:
# 📌 패치 완료: YOLO.train
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    240164  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 10, (32, 128)]
# ✅ torch.load monkey patch 완료
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1179380 parameters, 1179364 gradients, 12.7 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.3.113 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.17 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A6000, 48674MiB)
# engine/trainer: task=250422_143906_Train, mode=train, model=models/FLDetn/FLDet-n.yaml, data=Datasets/Crown Detection/data_iter_01.yaml, epochs=20, patience=20, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=tmp, name=250422_143907_FLDet-n_Crown Detection_Iter_1, exist_ok=True, pretrained=False, optimizer=AdamW, verbose=False, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.0001, weight_decay=0.0001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, testspeed=False, get_raw_output=False, decay_aug=False, close_copy_paste=0, close_mixup=0, tracker=botsort.yaml, save_dir=tmp/250422_143907_FLDet-n_Crown Detection_Iter_1
# Overriding model.yaml nc=10 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    239570  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 1, (32, 128)]
# 🛡️ YOLO.train() 패치됨 — cfg 제거 & safe_globals 등록
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1178786 parameters, 1178770 gradients, 12.7 GFLOPs
#
# Freezing layer 'model.12.dfl.conv.weight'
# /home/heiscold/CV_midterm_competition_code_v2/models/FLDetn/ultralytics/engine/trainer.py:246: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = amp.GradScaler(enabled=self.amp)
# train: Scan
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.17 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A6000, 48674MiB)
# ✅ Safe globals 등록 완료.
# FLDet-n summary (fused): 179 layers, 1199922 parameters, 641200 gradients, 12.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.80it/s]
#                    all        116        783      0.651      0.503      0.568       0.27
# Saving tmp/250422_143907_FLDet-n_Crown Detection_Iter_1/predictions.json...
#
# Evaluating pycocotools mAP using tmp/250422_143907_FLDet-n_Crown Detection_Iter_1/predictions.json and /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json...
# pycocotools unable to run: /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json file not found
# Speed: 0.1ms preprocess, 4.5ms inference, 0.0ms loss, 3.2ms postprocess per image
# Saving tmp/250422_143907_FLDet-n_Crown Detection_Iter_1/predictions.json...
#
# Evaluating pycocotools mAP using tmp/250422_143907_FLDet-n_Crown Detection_Iter_1/predictions.json and /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json...
# pycocotools unable to run: /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json file not found
# Results saved to tmp/250422_143907_FLDet-n_Crown Detection_Iter_1
# Transferred 597/597 items from pretrained weights
# ✅ Safe globals 등록 완료.
# ✅ Safe globals 등록 완료.
# 결과가 250422_143906_submission_2_2023220397_Iter_1_detection_results.json에 저장되었습니다.
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    240164  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 10, (32, 128)]
# ✅ torch.load monkey patch 완료
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1179380 parameters, 1179364 gradients, 12.7 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.3.113 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.17 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A6000, 48674MiB)
# engine/trainer: task=250422_144154_Train, mode=train, model=models/FLDetn/FLDet-n.yaml, data=Datasets/Crown Detection/data_iter_02.yaml, epochs=20, patience=20, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=tmp, name=250422_144154_FLDet-n_Crown Detection_Iter_2, exist_ok=True, pretrained=False, optimizer=AdamW, verbose=False, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.0001, weight_decay=0.0001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, testspeed=False, get_raw_output=False, decay_aug=False, close_copy_paste=0, close_mixup=0, tracker=botsort.yaml, save_dir=tmp/250422_144154_FLDet-n_Crown Detection_Iter_2
# Overriding model.yaml nc=10 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    239570  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 1, (32, 128)]
# 🛡️ YOLO.train() 패치됨 — cfg 제거 & safe_globals 등록
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1178786 parameters, 1178770 gradients, 12.7 GFLOPs
#
# Freezing layer 'model.12.dfl.conv.weight'
# train: Scanning Datasets/Crown Detection/labels... 348 images, 69 backgrounds, 0 corrupt: 100%|██████████| 348/348 [00:00<00:00, 3198.73it/s]
# train: New cache created: Datasets/Crown Detection/labels.cache
# val: Scanning Datasets/Crown Detection/labels... 116 images, 24 backgrounds, 0 corrupt: 100%|██████████| 116/116 [00:00<00:00, 2602.29it/s]
# val: New cache created: Datasets/Crown Detection/labels.cache
# Plotting labels to tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.0001) with parameter groups 98 weight(decay=0.0), 103 weight(decay=0.0001), 102 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to tmp/250422_144154_FLDet-n_Crown Detection_Iter_2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20        13G      3.359      3.263       3.74        145        640: 100%|██████████| 22/22 [00:06<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.40it/s]
#                    all        116        730    0.00207     0.0986    0.00127   0.000504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      13.2G       3.08      2.824      3.368        116        640: 100%|██████████| 22/22 [00:06<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.40it/s]
#                    all        116        730    0.00394      0.188    0.00366    0.00121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      12.4G      3.008      2.741      3.334        121        640: 100%|██████████| 22/22 [00:06<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.35it/s]
#                    all        116        730    0.00491      0.234    0.00568    0.00206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      12.9G      2.825      2.706       3.13        118        640: 100%|██████████| 22/22 [00:06<00:00,  3.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.20it/s]
#                    all        116        730    0.00546      0.251    0.00804    0.00227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      13.1G      2.719      2.662      3.077         56        640: 100%|██████████| 22/22 [00:06<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.11it/s]
#                    all        116        730     0.0208      0.527     0.0359     0.0111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      12.4G      2.702      2.543      3.059        109        640: 100%|██████████| 22/22 [00:06<00:00,  3.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#                    all        116        730      0.306      0.151      0.115     0.0383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      12.1G      2.629      2.483      2.963         96        640: 100%|██████████| 22/22 [00:06<00:00,  3.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.17it/s]
#                    all        116        730      0.397      0.274      0.255     0.0888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      12.8G      2.573      2.496      2.903         86        640: 100%|██████████| 22/22 [00:06<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.31it/s]
#                    all        116        730      0.324      0.233      0.212      0.084
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      13.1G      2.504      2.346      2.836        141        640: 100%|██████████| 22/22 [00:06<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.00it/s]
#                    all        116        730       0.42      0.316      0.317      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      12.4G      2.429       2.31       2.81        103        640: 100%|██████████| 22/22 [00:06<00:00,  3.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.87it/s]
#                    all        116        730      0.476      0.359      0.353      0.132
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      12.6G      2.219      2.271      2.659         99        640: 100%|██████████| 22/22 [00:06<00:00,  3.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.04it/s]
#                    all        116        730      0.249      0.232      0.192     0.0749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      12.4G      2.243      2.327      2.621         40        640: 100%|██████████| 22/22 [00:06<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.23it/s]
#                    all        116        730      0.442      0.399      0.404      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      12.4G      2.191      2.207      2.632         35        640: 100%|██████████| 22/22 [00:06<00:00,  3.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.13it/s]
#                    all        116        730      0.496      0.374       0.38      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      12.1G      2.163      2.224      2.588         74        640: 100%|██████████| 22/22 [00:06<00:00,  3.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.21it/s]
#                    all        116        730      0.425       0.44      0.392      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      12.4G      2.114      2.148      2.573         62        640: 100%|██████████| 22/22 [00:06<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.16it/s]
#                    all        116        730       0.56      0.466      0.482      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      12.5G       2.11       2.11      2.532         66        640: 100%|██████████| 22/22 [00:06<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.10it/s]
#                    all        116        730      0.465      0.445      0.404      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      12.2G      2.079      2.039      2.513         88        640: 100%|██████████| 22/22 [00:06<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.20it/s]
#                    all        116        730      0.576      0.445      0.493      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      12.4G      2.049      2.022      2.479         73        640: 100%|██████████| 22/22 [00:06<00:00,  3.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.20it/s]
#                    all        116        730      0.614      0.458      0.509      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      12.3G      2.034      2.009      2.439         73        640: 100%|██████████| 22/22 [00:06<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.14it/s]
#                    all        116        730      0.589      0.452      0.496      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      12.4G      2.028      1.972      2.445         32        640: 100%|██████████| 22/22 [00:06<00:00,  3.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.17it/s]
#                    all        116        730      0.619      0.473      0.529      0.256
#
# 20 epochs completed in 0.043 hours.
# Optimizer stripped from tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/weights/last.pt, 2.8MB
# ✅ Safe globals 등록 완료.
# ✅ Safe globals 등록 완료.
# Optimizer stripped from tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/weights/best.pt, 2.8MB
#
# Validating tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/weights/best.pt...
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.17 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A6000, 48674MiB)
# ✅ Safe globals 등록 완료.
# FLDet-n summary (fused): 179 layers, 1199922 parameters, 641200 gradients, 12.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.81it/s]
#                    all        116        730       0.62      0.473      0.529      0.256
# Saving tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/predictions.json...
#
# Evaluating pycocotools mAP using tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/predictions.json and /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json...
# pycocotools unable to run: /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json file not found
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 6.0ms postprocess per image
# Saving tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/predictions.json...
#
# Evaluating pycocotools mAP using tmp/250422_144154_FLDet-n_Crown Detection_Iter_2/predictions.json and /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json...
# pycocotools unable to run: /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json file not found
# Results saved to tmp/250422_144154_FLDet-n_Crown Detection_Iter_2
# Transferred 597/597 items from pretrained weights
# ✅ Safe globals 등록 완료.
# ✅ Safe globals 등록 완료.
# 결과가 250422_144154_submission_2_2023220397_Iter_2_detection_results.json에 저장되었습니다.
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    240164  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 10, (32, 128)]
# ✅ torch.load monkey patch 완료
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1179380 parameters, 1179364 gradients, 12.7 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.3.113 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.17 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A6000, 48674MiB)
# engine/trainer: task=250422_144643_Train, mode=train, model=models/FLDetn/FLDet-n.yaml, data=Datasets/Crown Detection/data_iter_03.yaml, epochs=20, patience=20, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=tmp, name=250422_144643_FLDet-n_Crown Detection_Iter_3, exist_ok=True, pretrained=False, optimizer=AdamW, verbose=False, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.0001, weight_decay=0.0001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, testspeed=False, get_raw_output=False, decay_aug=False, close_copy_paste=0, close_mixup=0, tracker=botsort.yaml, save_dir=tmp/250422_144643_FLDet-n_Crown Detection_Iter_3
# Overriding model.yaml nc=10 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    239570  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 1, (32, 128)]
# 🛡️ YOLO.train() 패치됨 — cfg 제거 & safe_globals 등록
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1178786 parameters, 1178770 gradients, 12.7 GFLOPs
#
# Freezing layer 'model.12.dfl.conv.weight'
# train: Scanning Datasets/Crown Detection/labels... 348 images, 66 backgrounds, 0 corrupt: 100%|██████████| 348/348 [00:00<00:00, 1155.45it/s]
# train: New cache created: Datasets/Crown Detection/labels.cache
# val: Scanning Datasets/Crown Detection/labels... 116 images, 27 backgrounds, 0 corrupt: 100%|██████████| 116/116 [00:00<00:00, 1676.95it/s]
# val: New cache created: Datasets/Crown Detection/labels.cache
# Plotting labels to tmp/250422_144643_FLDet-n_Crown Detection_Iter_3/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0
verbose=False, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.0001, weight_decay=0.0001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, testspeed=False, get_raw_output=False, decay_aug=False, close_copy_paste=0, close_mixup=0, tracker=botsort.yaml, save_dir=tmp/250422_152025_FLDet-n_Crown Detection_Iter_10
# Overriding model.yaml nc=10 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  ultralytics.nn.modules.csdet_block.IEPR      [32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   5                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  ultralytics.nn.modules.csdet_block.ECM       [64, 13, 0.25, 3]
#   7                  -1  1     52992  ultralytics.nn.modules.csdet_block.IEPR      [64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  10                  -1  1    175104  ultralytics.nn.modules.csdet_block.ECM       [128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  ultralytics.nn.modules.csdet_block.CSNeck3in [32, 64, 128, False, 2]
#  12                  -1  1    239570  ultralytics.nn.modules.head.Detect           ['SiLU', 'normal', 1, (32, 128)]
# 🛡️ YOLO.train() 패치됨 — cfg 제거 & safe_globals 등록
# ✅ Safe globals 등록 완료.
# FLDet-n summary: 409 layers, 1178786 parameters, 1178770 gradients, 12.7 GFLOPs
#
# Freezing layer 'model.12.dfl.conv.weight'
# train: Scanning Datasets/Crown Detection/labels... 348 images, 67 backgrounds, 0 corrupt: 100%|██████████| 348/348 [00:00<00:00, 1608.50it/s]
# train: New cache created: Datasets/Crown Detection/labels.cache
# val: Scanning Datasets/Crown Detection/labels... 116 images, 25 backgrounds, 0 corrupt: 100%|██████████| 116/116 [00:00<00:00, 1676.90it/s]
# val: New cache created: Datasets/Crown Detection/labels.cache
# Plotting labels to tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.0001) with parameter groups 98 weight(decay=0.0), 103 weight(decay=0.0001), 102 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to tmp/250422_152025_FLDet-n_Crown Detection_Iter_10
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      12.8G       3.33      3.322       3.72        155        640: 100%|██████████| 22/22 [00:06<00:00,  3.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.53it/s]
#                    all        116        700    0.00293      0.146    0.00215   0.000836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      12.4G      3.065       2.71      3.364        154        640: 100%|██████████| 22/22 [00:06<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.65it/s]
#                    all        116        700    0.00494      0.246    0.00831    0.00329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      12.3G      2.971      2.777      3.236        179        640: 100%|██████████| 22/22 [00:06<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.29it/s]
#                    all        116        700    0.00503       0.25    0.00728     0.0029
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      13.4G       2.87      2.709      3.138        149        640: 100%|██████████| 22/22 [00:06<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.57it/s]
#                    all        116        700    0.00744      0.311     0.0108    0.00366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      12.9G      2.779      2.684      3.067         78        640: 100%|██████████| 22/22 [00:06<00:00,  3.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.08it/s]
#                    all        116        700      0.111       0.19     0.0766     0.0313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      12.8G      2.623      2.567      2.974         85        640: 100%|██████████| 22/22 [00:06<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.21it/s]
#                    all        116        700      0.181      0.131     0.0934     0.0347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20        13G      2.552      2.439      2.912        102        640: 100%|██████████| 22/22 [00:06<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.27it/s]
#                    all        116        700      0.308       0.21      0.158     0.0411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20        13G      2.609       2.44      2.905        102        640: 100%|██████████| 22/22 [00:06<00:00,  3.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.70it/s]
#                    all        116        700      0.315      0.299      0.255     0.0952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      12.4G      2.507      2.443      2.847        147        640: 100%|██████████| 22/22 [00:06<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.18it/s]
#                    all        116        700      0.335      0.261       0.24     0.0713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      12.7G      2.392      2.359      2.738         66        640: 100%|██████████| 22/22 [00:06<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.05it/s]
#                    all        116        700      0.411       0.37      0.325      0.133
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      12.3G      2.213      2.313      2.611         89        640: 100%|██████████| 22/22 [00:06<00:00,  3.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.20it/s]
#                    all        116        700      0.376      0.369      0.333      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      12.4G      2.242       2.34      2.627         79        640: 100%|██████████| 22/22 [00:06<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.37it/s]
#                    all        116        700      0.482      0.377      0.361      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      12.4G      2.192      2.237      2.573         63        640: 100%|██████████| 22/22 [00:06<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.09it/s]
#                    all        116        700      0.489      0.402      0.397      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      12.4G      2.174      2.235      2.533         86        640: 100%|██████████| 22/22 [00:06<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.17it/s]
#                    all        116        700      0.547      0.409      0.446      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      11.9G      2.122      2.121      2.487         75        640: 100%|██████████| 22/22 [00:06<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.30it/s]
#                    all        116        700      0.467      0.403      0.391      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      12.6G      2.125      2.135      2.513         78        640: 100%|██████████| 22/22 [00:06<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.22it/s]
#                    all        116        700      0.625      0.443      0.496      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      12.3G      2.103      2.086      2.465         63        640: 100%|██████████| 22/22 [00:06<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.34it/s]
#                    all        116        700      0.597      0.456      0.496      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      12.4G      2.045      2.061      2.444         48        640: 100%|██████████| 22/22 [00:06<00:00,  3.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.25it/s]
#                    all        116        700      0.554      0.426       0.46        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      12.2G      2.069      2.059      2.443         56        640: 100%|██████████| 22/22 [00:06<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.27it/s]
#                    all        116        700      0.651      0.446      0.518      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      12.4G      1.993      2.003      2.388         38        640: 100%|██████████| 22/22 [00:06<00:00,  3.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  5.35it/s]
#                    all        116        700      0.639      0.464      0.526      0.245
#
# 20 epochs completed in 0.043 hours.
# ✅ Safe globals 등록 완료.
# Optimizer stripped from tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/weights/last.pt, 2.8MB
# Optimizer stripped from tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/weights/best.pt, 2.8MB
#
# Validating tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/weights/best.pt...
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.17 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A6000, 48674MiB)
# ✅ Safe globals 등록 완료.
# ✅ Safe globals 등록 완료.
# FLDet-n summary (fused): 179 layers, 1199922 parameters, 641200 gradients, 12.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
#                    all        116        700      0.638      0.464      0.526      0.245
# Saving tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/predictions.json...
#
# Evaluating pycocotools mAP using tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/predictions.json and /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json...
# pycocotools unable to run: /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json file not found
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 5.8ms postprocess per image
# Saving tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/predictions.json...
#
# Evaluating pycocotools mAP using tmp/250422_152025_FLDet-n_Crown Detection_Iter_10/predictions.json and /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json...
# pycocotools unable to run: /home/heiscold/CV_midterm_competition_code_v2/Datasets/Crown Detection/annotations/instances_val2017.json file not found
# Results saved to tmp/250422_152025_FLDet-n_Crown Detection_Iter_10
# Transferred 597/597 items from pretrained weights
# ✅ Safe globals 등록 완료.
# ✅ Safe globals 등록 완료.
# 결과가 250422_152025_submission_2_2023220397_Iter_10_detection_results.json에 저장되었습니다.

# %%
# 분석 방향에 따라 전체 결과를 모아 평균-표준편차-통계테스트 결과 저장 

keep_columns = ['Iteration','Submission Function']
keep_measures = ['IoU','Dice','Precision','Recall']  

reduction = 'Iteration'
row = 'Measure Type'
column = 'Submission Function'
reference_column = 'submission_2_2023220397'

custom_fmt_template = '{mean_fmt} ± {std_fmt} {significance}'
significance_levels = [0.1, 0.05, 0.01]
decimal_places = 3
transpose = True
make_tables(csv_filename, keep_columns, keep_measures, reduction, row, column,  
            reference_column, custom_fmt_template, significance_levels, decimal_places, transpose)
# Out:
# CSV 파일로 저장 완료: Evaluation_Results_250422_143906_agg.csv
